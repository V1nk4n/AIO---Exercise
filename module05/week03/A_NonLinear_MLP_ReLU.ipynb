# %% [markdown]
# ## **0. Download dataset**
# **Note:** If you can't download using gdown due to limited number of downloads, please download it manually and upload it to your drive, then copy it from the drive to colab.
# ```python
# from google.colab import drive
#
# drive.mount('/content/drive')
# !cp /path/to/dataset/on/your/drive .
# ```

# %%
# https://drive.google.com/file/d/1SqSn_8rxkk-Qvu4JLMcN_3ZFGDNa6P_V/view?usp=sharing
# !gdown --id 1SqSn_8rxkk-Qvu4JLMcN_3ZFGDNa6P_V
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1SqSn_8rxkk-Qvu4JLMcN_3ZFGDNa6P_V
# To: /content/NonLinear_data.npy
# 100% 5.57k/5.57k [00:00<00:00, 17.7MB/s]

# %% [markdown]
# ## **1. Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# %% [markdown]
# ## **2. Read dataset**

# %%
data_path = '/content/NonLinear_data.npy'
data = np.load(data_path, allow_pickle=True).item()
X, y = data['X'], data['labels']

# %% [markdown]
# ## **3. Train/val/test split**

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
print(f'Number of training samples: {X_train.shape[0]}')
print(f'Number of val samples: {X_val.shape[0]}')
print(f'Number of test samples: {X_test.shape[0]}')
# Out:
# Number of training samples: 210
# Number of val samples: 60
# Number of test samples: 30

# %% [markdown]
# ## **4. Data Normalization**

# %% [markdown]
# ## **5. Create PyTorch DataLoader**

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
test_dataset = CustomDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## **6. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.linear1(x)
        x = self.relu(x)
        out = self.output(x)
        return out.squeeze(1)

input_dims = X_train.shape[1]
y_train_tensor = torch.tensor(y_train) if not isinstance(y_train, torch.Tensor) else y_train
output_dims = torch.unique(y_train_tensor).shape[0]
hidden_dims = 128
model = MLP(input_dims, hidden_dims, output_dims).to(device)

lr = 1e-1
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %% [markdown]
# ## **7. Training**

# %%
def compute_accuracy(y_hat, y_true):
    _, y_hat = torch.max(y_hat, dim=1)
    correct = (y_hat == y_true).sum().item()
    accuracy = correct / len(y_true)
    return accuracy

# %%
epochs = 100
train_losses = []
val_losses = []
train_accs = []
val_accs = []

for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    train_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device).float()
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        train_predict.append(outputs.detach().cpu())
        train_target.append(y_samples.cpu())

    train_loss /= len(train_loader)
    train_losses.append(train_loss)

    train_predict = torch.cat(train_predict)
    train_target = torch.cat(train_target)
    train_acc = compute_accuracy(train_predict, train_target)
    train_accs.append(train_acc)

    val_loss = 0.0
    val_target = []
    val_predict = []
    model.eval()
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device).float()
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_loss += criterion(outputs, y_samples).item()

            val_predict.append(outputs.cpu())
            val_target.append(y_samples.cpu())

    val_loss /= len(val_loader)
    val_losses.append(val_loss)

    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = compute_accuracy(val_predict, val_target)
    val_accs.append(val_acc)

    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 0.900	Validation loss: 0.905
#
# EPOCH 2:	Training loss: 0.819	Validation loss: 0.871
#
# EPOCH 3:	Training loss: 0.781	Validation loss: 0.862
#
# EPOCH 4:	Training loss: 0.769	Validation loss: 0.851
#
# EPOCH 5:	Training loss: 0.737	Validation loss: 0.840
#
# EPOCH 6:	Training loss: 0.728	Validation loss: 0.827
#
# EPOCH 7:	Training loss: 0.726	Validation loss: 0.821
#
# EPOCH 8:	Training loss: 0.712	Validation loss: 0.811
#
# EPOCH 9:	Training loss: 0.710	Validation loss: 0.807
#
# EPOCH 10:	Training loss: 0.711	Validation loss: 0.809
#
# EPOCH 11:	Training loss: 0.704	Validation loss: 0.804
#
# EPOCH 12:	Training loss: 0.704	Validation loss: 0.804
#
# EPOCH 13:	Training loss: 0.693	Validation loss: 0.793
#
# EPOCH 14:	Training loss: 0.683	Validation loss: 0.789
#
# EPOCH 15:	Training loss: 0.681	Validation loss: 0.784
#
# EPOCH 16:	Training loss: 0.680	Validation loss: 0.805
#
# EPOCH 17:	Training loss: 0.686	Validation loss: 0.781
#
# EPOCH 18:	Training loss: 0.655	Validation loss: 0.774
#
# EPOCH 19:	Training loss: 0.684	Validation loss: 0.777
#
# EPOCH 20:	Training loss: 0.668	Validation loss: 0.767
#
# EPOCH 21:	Training loss: 0.657	Validation loss: 0.763
#
# EPOCH 22:	Training loss: 0.649	Validation loss: 0.762
#
# EPOCH 23:	Training loss: 0.644	Validation loss: 0.754
#
# EPOCH 24:	Training loss: 0.646	Validation loss: 0.754
#
# EPOCH 25:	Training loss: 0.639	Validation loss: 0.749
#
# EPOCH 26:	Training loss: 0.648	Validation loss: 0.744
#
# EPOCH 27:	Training loss: 0.640	Validation loss: 0.745
#
# EPOCH 28:	Training loss: 0.631	Validation loss: 0.744
#
# EPOCH 29:	Training loss: 0.619	Validation loss: 0.735
#
# EPOCH 30:	Training loss: 0.644	Validation loss: 0.731
#
# EPOCH 31:	Training loss: 0.620	Validation loss: 0.725
#
# EPOCH 32:	Training loss: 0.605	Validation loss: 0.723
#
# EPOCH 33:	Training loss: 0.611	Validation loss: 0.719
#
# EPOCH 34:	Training loss: 0.608	Validation loss: 0.720
#
# EPOCH 35:	Training loss: 0.609	Validation loss: 0.716
#
# EPOCH 36:	Training loss: 0.601	Validation loss: 0.713
#
# EPOCH 37:	Training loss: 0.593	Validation loss: 0.706
#
# EPOCH 38:	Training loss: 0.599	Validation loss: 0.701
#
# EPOCH 39:	Training loss: 0.598	Validation loss: 0.705
#
# EPOCH 40:	Training loss: 0.600	Validation loss: 0.695
#
# EPOCH 41:	Training loss: 0.592	Validation loss: 0.689
#
# EPOCH 42:	Training loss: 0.602	Validation loss: 0.685
#
# EPOCH 43:	Training loss: 0.596	Validation loss: 0.684
#
# EPOCH 44:	Training loss: 0.574	Validation loss: 0.676
#
# EPOCH 45:	Training loss: 0.578	Validation loss: 0.673
#
# EPOCH 46:	Training loss: 0.577	Validation loss: 0.670
#
# EPOCH 47:	Training loss: 0.583	Validation loss: 0.669
#
# EPOCH 48:	Training loss: 0.567	Validation loss: 0.672
#
# EPOCH 49:	Training loss: 0.571	Validation loss: 0.657
#
# EPOCH 50:	Training loss: 0.566	Validation loss: 0.653
#
# EPOCH 51:	Training loss: 0.547	Validation loss: 0.654
#
# EPOCH 52:	Training loss: 0.555	Validation loss: 0.649
#
# EPOCH 53:	Training loss: 0.546	Validation loss: 0.645
#
# EPOCH 54:	Training loss: 0.543	Validation loss: 0.646
#
# EPOCH 55:	Training loss: 0.560	Validation loss: 0.639
#
# EPOCH 56:	Training loss: 0.550	Validation loss: 0.632
#
# EPOCH 57:	Training loss: 0.534	Validation loss: 0.634
#
# EPOCH 58:	Training loss: 0.532	Validation loss: 0.628
#
# EPOCH 59:	Training loss: 0.533	Validation loss: 0.622
#
# EPOCH 60:	Training loss: 0.525	Validation loss: 0.621
#
# EPOCH 61:	Training loss: 0.531	Validation loss: 0.618
#
# EPOCH 62:	Training loss: 0.523	Validation loss: 0.614
#
# EPOCH 63:	Training loss: 0.512	Validation loss: 0.609
#
# EPOCH 64:	Training loss: 0.523	Validation loss: 0.607
#
# EPOCH 65:	Training loss: 0.525	Validation loss: 0.602
#
# EPOCH 66:	Training loss: 0.515	Validation loss: 0.598
#
# EPOCH 67:	Training loss: 0.508	Validation loss: 0.595
#
# EPOCH 68:	Training loss: 0.521	Validation loss: 0.589
#
# EPOCH 69:	Training loss: 0.496	Validation loss: 0.593
#
# EPOCH 70:	Training loss: 0.515	Validation loss: 0.589
#
# EPOCH 71:	Training loss: 0.500	Validation loss: 0.579
#
# EPOCH 72:	Training loss: 0.500	Validation loss: 0.578
#
# EPOCH 73:	Training loss: 0.494	Validation loss: 0.573
#
# EPOCH 74:	Training loss: 0.488	Validation loss: 0.570
#
# EPOCH 75:	Training loss: 0.501	Validation loss: 0.567
#
# EPOCH 76:	Training loss: 0.478	Validation loss: 0.564
#
# EPOCH 77:	Training loss: 0.489	Validation loss: 0.560
#
# EPOCH 78:	Training loss: 0.488	Validation loss: 0.563
#
# EPOCH 79:	Training loss: 0.490	Validation loss: 0.553
#
# EPOCH 80:	Training loss: 0.491	Validation loss: 0.550
#
# EPOCH 81:	Training loss: 0.477	Validation loss: 0.553
#
# EPOCH 82:	Training loss: 0.483	Validation loss: 0.542
#
# EPOCH 83:	Training loss: 0.468	Validation loss: 0.542
#
# EPOCH 84:	Training loss: 0.469	Validation loss: 0.536
#
# EPOCH 85:	Training loss: 0.471	Validation loss: 0.536
#
# EPOCH 86:	Training loss: 0.453	Validation loss: 0.532
#
# EPOCH 87:	Training loss: 0.468	Validation loss: 0.526
#
# EPOCH 88:	Training loss: 0.469	Validation loss: 0.528
#
# EPOCH 89:	Training loss: 0.456	Validation loss: 0.521
#
# EPOCH 90:	Training loss: 0.458	Validation loss: 0.524
#
# EPOCH 91:	Training loss: 0.446	Validation loss: 0.521
#
# EPOCH 92:	Training loss: 0.445	Validation loss: 0.512
#
# EPOCH 93:	Training loss: 0.451	Validation loss: 0.518
#
# EPOCH 94:	Training loss: 0.451	Validation loss: 0.506
#
# EPOCH 95:	Training loss: 0.443	Validation loss: 0.503
#
# EPOCH 96:	Training loss: 0.432	Validation loss: 0.502
#
# EPOCH 97:	Training loss: 0.428	Validation loss: 0.499
#
# EPOCH 98:	Training loss: 0.432	Validation loss: 0.494
#
# EPOCH 99:	Training loss: 0.438	Validation loss: 0.492
#
# EPOCH 100:	Training loss: 0.426	Validation loss: 0.489

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ## **8. Evaluation**

# %%
test_target = []
test_predict = []
model.eval()
with torch.no_grad():
    for X_samples, y_samples in test_loader:
        X_samples = X_samples.to(device).float()
        y_samples = y_samples.to(device)
        outputs = model(X_samples)

        test_predict.append(outputs.cpu())
        test_target.append(y_samples.cpu())

    test_predict = torch.cat(test_predict)
    test_target = torch.cat(test_target)
    test_acc = compute_accuracy(test_predict, test_target)

    print('Evaluation on test set:')
    print(f'Accuracy: {test_acc}')
# Out:
# Evaluation on test set:
# Accuracy: 0.7666666666666667
