# %% [markdown]
# ## **0. Download dataset**
# **Note:** If you can't download using gdown due to limited number of downloads, please download it manually and upload it to your drive, then copy it from the drive to colab.
# ```python
# from google.colab import drive
#
# drive.mount('/content/drive')
# !cp /path/to/dataset/on/your/drive .
# ```

# %%
# https://drive.google.com/file/d/1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu/view?usp=sharing
# !gdown --id 1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# To: /content/Auto_MPG_data.csv
# 100% 15.4k/15.4k [00:00<00:00, 54.3MB/s]

# %% [markdown]
# ## **1. Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# %% [markdown]
# ## **2. Read dataset**

# %%
dataset_path = '/content/Auto_MPG_data.csv'
dataset = pd.read_csv(dataset_path)
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0        86.0  2790.0          15.6
# 388  44.0          4          97.0        52.0  2130.0          24.6
# 389  32.0          4         135.0        84.0  2295.0          11.6
# 390  28.0          4         120.0        79.0  2625.0          18.6
# 391  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan  USA
# 0            70       0      0    1
# 1            70       0      0    1
# 2            70       0      0    1
# 3            70       0      0    1
# 4            70       0      0    1
# ..          ...     ...    ...  ...
# 387          82       0      0    1
# 388          82       1      0    0
# 389          82       0      0    1
# 390          82       0      0    1
# 391          82       0      0    1
#
# [392 rows x 10 columns]

# %% [markdown]
# ## **3. Preprocessing data**

# %% [markdown]
# ### **3.1. X, y split**

# %%
X = dataset.drop(columns='MPG').values
y = dataset['MPG'].values

# %% [markdown]
# ### **3.2. Train/val/test split**

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
print(f'Number of training samples: {X_train.shape[0]}')
print(f'Number of val samples: {X_val.shape[0]}')
print(f'Number of test samples: {X_test.shape[0]}')
# Out:
# Number of training samples: 273
# Number of val samples: 79
# Number of test samples: 40

# %% [markdown]
# ### **3.3. Data Normalization**

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %% [markdown]
# ## **4. Create PyTorch DataLoader**

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## **5. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        out = self.output(x)
        return out.squeeze(1)

input_dims = X_train.shape[1]
output_dims = 1
hidden_dims = 64

model = MLP(input_dims=input_dims, hidden_dims=hidden_dims, output_dims=output_dims).to(device)
lr = 1e-2
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %% [markdown]
# ## **6. Training**

# %%
def r_squared(y_true, y_pred):
    y_true = torch.Tensor(y_true).to(device)
    y_pred = torch.Tensor(y_pred).to(device)
    mean_true = torch.mean(y_true)
    ss_tot = torch.sum((y_true - mean_true) ** 2)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

# %%
epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []


for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        train_predict += outputs.tolist()
        train_target += y_samples.tolist()
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_target, train_predict))
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_predict += outputs.tolist()
            val_target += y_samples.tolist()
            loss = criterion(outputs, y_samples)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_target, val_predict))
    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 282.769	Validation loss: 88.671
#
# EPOCH 2:	Training loss: 137.646	Validation loss: 72.294
#
# EPOCH 3:	Training loss: 71.070	Validation loss: 19.371
#
# EPOCH 4:	Training loss: 24.804	Validation loss: 186.688
#
# EPOCH 5:	Training loss: 92.399	Validation loss: 19.700
#
# EPOCH 6:	Training loss: 17.711	Validation loss: 13.641
#
# EPOCH 7:	Training loss: 19.708	Validation loss: 12.308
#
# EPOCH 8:	Training loss: 38.663	Validation loss: 47.827
#
# EPOCH 9:	Training loss: 17.413	Validation loss: 42.953
#
# EPOCH 10:	Training loss: 25.419	Validation loss: 41.527
#
# EPOCH 11:	Training loss: 27.256	Validation loss: 19.484
#
# EPOCH 12:	Training loss: 9.713	Validation loss: 5.797
#
# EPOCH 13:	Training loss: 14.974	Validation loss: 16.683
#
# EPOCH 14:	Training loss: 12.200	Validation loss: 13.667
#
# EPOCH 15:	Training loss: 14.411	Validation loss: 8.119
#
# EPOCH 16:	Training loss: 10.668	Validation loss: 19.283
#
# EPOCH 17:	Training loss: 12.520	Validation loss: 14.454
#
# EPOCH 18:	Training loss: 15.566	Validation loss: 12.801
#
# EPOCH 19:	Training loss: 14.406	Validation loss: 5.224
#
# EPOCH 20:	Training loss: 7.194	Validation loss: 4.940
#
# EPOCH 21:	Training loss: 8.390	Validation loss: 4.551
#
# EPOCH 22:	Training loss: 6.155	Validation loss: 5.178
#
# EPOCH 23:	Training loss: 10.217	Validation loss: 52.754
#
# EPOCH 24:	Training loss: 10.878	Validation loss: 14.815
#
# EPOCH 25:	Training loss: 8.995	Validation loss: 8.515
#
# EPOCH 26:	Training loss: 10.291	Validation loss: 6.589
#
# EPOCH 27:	Training loss: 6.281	Validation loss: 6.220
#
# EPOCH 28:	Training loss: 10.717	Validation loss: 4.776
#
# EPOCH 29:	Training loss: 6.551	Validation loss: 11.312
#
# EPOCH 30:	Training loss: 17.460	Validation loss: 4.710
#
# EPOCH 31:	Training loss: 7.988	Validation loss: 5.979
#
# EPOCH 32:	Training loss: 6.948	Validation loss: 5.930
#
# EPOCH 33:	Training loss: 7.369	Validation loss: 4.561
#
# EPOCH 34:	Training loss: 6.691	Validation loss: 6.146
#
# EPOCH 35:	Training loss: 7.503	Validation loss: 6.098
#
# EPOCH 36:	Training loss: 5.900	Validation loss: 5.712
#
# EPOCH 37:	Training loss: 6.012	Validation loss: 6.031
#
# EPOCH 38:	Training loss: 7.442	Validation loss: 10.096
#
# EPOCH 39:	Training loss: 7.460	Validation loss: 15.009
#
# EPOCH 40:	Training loss: 7.771	Validation loss: 5.578
#
# EPOCH 41:	Training loss: 5.955	Validation loss: 21.482
#
# EPOCH 42:	Training loss: 8.030	Validation loss: 5.279
#
# EPOCH 43:	Training loss: 7.336	Validation loss: 30.499
#
# EPOCH 44:	Training loss: 10.174	Validation loss: 10.304
#
# EPOCH 45:	Training loss: 6.410	Validation loss: 4.930
#
# EPOCH 46:	Training loss: 8.290	Validation loss: 6.498
#
# EPOCH 47:	Training loss: 6.394	Validation loss: 6.652
#
# EPOCH 48:	Training loss: 5.418	Validation loss: 6.478
#
# EPOCH 49:	Training loss: 6.633	Validation loss: 9.999
#
# EPOCH 50:	Training loss: 6.687	Validation loss: 12.410
#
# EPOCH 51:	Training loss: 8.051	Validation loss: 7.570
#
# EPOCH 52:	Training loss: 11.189	Validation loss: 4.971
#
# EPOCH 53:	Training loss: 7.316	Validation loss: 4.915
#
# EPOCH 54:	Training loss: 6.593	Validation loss: 5.283
#
# EPOCH 55:	Training loss: 5.390	Validation loss: 4.993
#
# EPOCH 56:	Training loss: 5.454	Validation loss: 5.936
#
# EPOCH 57:	Training loss: 7.561	Validation loss: 7.199
#
# EPOCH 58:	Training loss: 6.953	Validation loss: 18.923
#
# EPOCH 59:	Training loss: 7.491	Validation loss: 7.371
#
# EPOCH 60:	Training loss: 5.680	Validation loss: 4.610
#
# EPOCH 61:	Training loss: 5.767	Validation loss: 9.370
#
# EPOCH 62:	Training loss: 11.406	Validation loss: 4.659
#
# EPOCH 63:	Training loss: 6.787	Validation loss: 14.878
#
# EPOCH 64:	Training loss: 6.301	Validation loss: 6.027
#
# EPOCH 65:	Training loss: 8.694	Validation loss: 5.171
#
# EPOCH 66:	Training loss: 5.379	Validation loss: 5.159
#
# EPOCH 67:	Training loss: 6.194	Validation loss: 6.403
#
# EPOCH 68:	Training loss: 11.018	Validation loss: 7.515
#
# EPOCH 69:	Training loss: 7.230	Validation loss: 8.857
#
# EPOCH 70:	Training loss: 5.996	Validation loss: 5.228
#
# EPOCH 71:	Training loss: 5.185	Validation loss: 4.727
#
# EPOCH 72:	Training loss: 5.948	Validation loss: 8.849
#
# EPOCH 73:	Training loss: 6.477	Validation loss: 9.140
#
# EPOCH 74:	Training loss: 6.060	Validation loss: 5.408
#
# EPOCH 75:	Training loss: 5.529	Validation loss: 17.790
#
# EPOCH 76:	Training loss: 7.770	Validation loss: 20.679
#
# EPOCH 77:	Training loss: 11.419	Validation loss: 7.446
#
# EPOCH 78:	Training loss: 6.722	Validation loss: 5.313
#
# EPOCH 79:	Training loss: 5.792	Validation loss: 10.687
#
# EPOCH 80:	Training loss: 7.797	Validation loss: 5.572
#
# EPOCH 81:	Training loss: 11.617	Validation loss: 6.641
#
# EPOCH 82:	Training loss: 5.682	Validation loss: 5.454
#
# EPOCH 83:	Training loss: 5.690	Validation loss: 8.486
#
# EPOCH 84:	Training loss: 5.367	Validation loss: 5.118
#
# EPOCH 85:	Training loss: 4.961	Validation loss: 6.509
#
# EPOCH 86:	Training loss: 4.744	Validation loss: 6.292
#
# EPOCH 87:	Training loss: 5.121	Validation loss: 7.870
#
# EPOCH 88:	Training loss: 5.287	Validation loss: 5.144
#
# EPOCH 89:	Training loss: 4.712	Validation loss: 5.641
#
# EPOCH 90:	Training loss: 7.039	Validation loss: 5.594
#
# EPOCH 91:	Training loss: 5.422	Validation loss: 8.563
#
# EPOCH 92:	Training loss: 7.686	Validation loss: 5.443
#
# EPOCH 93:	Training loss: 6.258	Validation loss: 5.074
#
# EPOCH 94:	Training loss: 8.955	Validation loss: 7.262
#
# EPOCH 95:	Training loss: 6.587	Validation loss: 5.783
#
# EPOCH 96:	Training loss: 8.263	Validation loss: 21.047
#
# EPOCH 97:	Training loss: 7.046	Validation loss: 10.228
#
# EPOCH 98:	Training loss: 7.295	Validation loss: 8.206
#
# EPOCH 99:	Training loss: 6.361	Validation loss: 5.547
#
# EPOCH 100:	Training loss: 5.916	Validation loss: 4.991

# %% [markdown]
# ## **7. Evaluation**

# %%
model.eval()
with torch.no_grad():
    device = next(model.parameters()).device
    X_test = X_test.to(device)
    y_test = y_test.to(device)

    y_hat = model(X_test)
    test_set_r2 = r_squared(y_hat, y_test)
    print('Evaluation on test set:')
    print(f'R2: {test_set_r2}')
# Out:
# Evaluation on test set:
# R2: 0.8383038640022278
